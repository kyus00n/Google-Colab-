# %%
from google.colab import drive
drive.mount('/content/gdrive')
from google.colab.patches import cv2_imshow

import numpy as np
import cv2
# 새 영상 생성하기
img1 = np.empty((240, 320), dtype=np.uint8) #흑백 이미지
img2 = np.zeros((240, 320, 3), dtype=np.uint8) #컬러 이미지, 초기 이미지를 0으로 채운다 검은색 출력

# grayscale image
# color image
img3 = np.ones((240, 320), dtype=np.uint8) * 255    # dark gray
img4 = np.full((240, 320, 3), (0, 255, 255), dtype=np.uint8)  # yellow, (0, 255, 255)는 임의의 컬러 지정, R과 G를 같이 내보낸다.따라서 Yellow
cv2_imshow(img1)
cv2_imshow(img2)
cv2_imshow(img3)
cv2_imshow(img4)
# cv2.waitKey()
# cv2.destroyAllWindows()

# 영상 복사
img1 = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/data/HappyFish.jpg')
img2 = img1 #img1과 img2는 서로 영향을 미치며 공유
img3 = img1.copy() #img3는 독립적

#img1.fill(255)
cv2_imshow(img1)
cv2_imshow(img2)
cv2_imshow(img3)

# cv2.waitKey()
# cv2.destroyAllWindows()

# 부분 영상 추출
img1 = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/data/HappyFish.jpg')
img2 = img1[40:120, 30:150]  # numpy.ndarray의 슬라이싱, img1과 img2는 서로 공유
img3 = img1[40:120, 30:150].copy() # copy이기 때문에 별도의 장치에 분리
img2.fill(0)
cv2_imshow(img1)
cv2_imshow(img2)
cv2_imshow(img3)

# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# <PIL.Image.Image image mode=L size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=L size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=259x194>
# <PIL.Image.Image image mode=RGB size=259x194>
# <PIL.Image.Image image mode=RGB size=259x194>
# <PIL.Image.Image image mode=RGB size=259x194>
# <PIL.Image.Image image mode=RGB size=120x80>
# <PIL.Image.Image image mode=RGB size=120x80>
